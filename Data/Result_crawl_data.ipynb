# %% [markdown]
# <a href="https://colab.research.google.com/github/PhanTung-06/CS114.L21/blob/main/Data/Result_crawl_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1 align="center"><b>BÁO CÁO KẾT QUẢ QUÁ TRÌNH THU THẬP DATASET CHO BÀI TOÁN SARCASM DETECTION IN NEWS HEADLINE</b></h1>

# %% [markdown]
# #**1. NHÓM THỰC HIỆN**
# - Phan Tung - 19522495
# - Huỳnh Thị Mỹ Duyên - 19521438
# - Hoàng Tiến Dũng - 19521388
#
# #**2. BÁO CÁO KẾT QUẢ**
#
# ###**Nhóm đã thực hiện crawl 7 trang web gồm:**
# 1.   Trang tin châm biếm:
# - The onion: https://www.theonion.com/
# - Betootaadvocate: https://www.betootaadvocate.com/
# - Dailybonnet: https://dailybonnet.com/
# - The Civilian: http://www.thecivilian.co.nz/
# 2.   Trang tin chính thống:
# - The sun: https://www.thesun.co.uk/
# - The Mirror: https://www.mirror.co.uk/
# - Newsweek: https://www.newsweek.com/
#
#
# ###**Công cụ:**
# - Python3 và BeautifulSoup4
#
#
# ###**Sau đây là kết quả thu được:**
#
# |News web| Number of records| Is sarcasm| From year|
# |---|---|---|---|
# |The Sun| 8400| 0| 2018|
# |The Mirror| 10000| 0| 2017|
# |Newsweek| 4000| 0| 2017|
# |The Civilian| 664| 1| 2013|
# |Dailybonnet| 1800| 1| 2016|
# |Betootaadvocate|10480|1|2015|
# |The Onion|6000|1|2007|
# |Sarcasm|18944|
# |No Sarcasm|22400|
# |Total|41344|
